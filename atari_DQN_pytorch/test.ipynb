# %%
import gym
import matplotlib.pyplot as plt

# %%
from env_wraped import make_env

# %%
env_name = "ALE/Breakout-v5"
render_mode="rgb_array"
env = make_env(env_name, render_mode)

# %%
obs, info = env.reset()

for _ in range(10):
    obs, _, _, _, info = env.step(env.action_space.sample())

plt.title("game image")
plt.imshow(env.render())
plt.show()
# Out:
# D:\Anaconda\envs\rl\lib\site-packages\gym\utils\passive_env_checker.py:233: DeprecationWarning: `np.bool8` is a deprecated alias for `np.bool_`.  (Deprecated NumPy 1.24)
#   if not isinstance(terminated, (bool, np.bool8)):
# D:\Anaconda\envs\rl\lib\site-packages\gym\utils\passive_env_checker.py:289: UserWarning: WARN: No render fps was declared in the environment (env.metadata['render_fps'] is None or not defined), rendering may occur at inconsistent fps.
#   logger.warn(

# %%
plt.imshow(obs[1])

# %%
plt.imshow(obs[2])

# %%
plt.imshow(obs[3])
